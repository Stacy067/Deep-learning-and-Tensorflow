# %% [markdown]
# <a href="https://colab.research.google.com/github/Stacy067/Deep-learning-and-Tensorflow/blob/main/TF_Certificate_Category_5_(%EA%B0%95%EC%9D%98)%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Category 5
#
# Sequence (시계열) 데이터 다루기

# %% [markdown]
# ## 확인

# %% [markdown]
# 1. GPU 옵션 켜져 있는지 확인할 것!!! (수정 - 노트설정 - 하드웨어설정 (GPU))

# %% [markdown]
# ## 순서

# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행합니다.
# 3. **모델링(model)**: 모델을 정의합니다.
# 4. **컴파일(compile)**: 모델을 생성합니다.
# 5. **학습 (fit)**: 모델을 학습시킵니다.

# %% [markdown]
# ## 문제

# %% [markdown]
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv
# provided.
#
# Your neural network is expected to have an MAE
# of at least 20, with top marks going to one with an MAE
# of around 15.
#
# At the bottom is provided some testing
# code should you want to check before uploading which measures
# the MAE for you.
#
# Strongly recommend you test your model with
# this to be able to see how it performs.
#
#
#
# -------------------------------
# **Sequence(시퀀스)**
#
# Sunspots.csv를 사용하여 **태양 흑점 활동(sunspot)**을 예측하는 인공신경망을 만듭니다.
#
# MAE 오차 기준으로 최소 20이하로 예측할 것을 권장하며, 탑 랭킹에 들려면 MAE 15 근처에 도달해야합니다.
#
# 아래 주어진 샘플코드는 당신의 모델을 테스트 하는 용도로 활용할 수 있습니다.

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## 필요한 모듈 import

# %%
import csv
import tensorflow as tf
import numpy as np
import urllib

from tensorflow.keras.layers import Dense, LSTM, Lambda, Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import Huber

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
urllib.request.urlretrieve(url, 'sunspots.csv')
# Out:
# ('sunspots.csv', <http.client.HTTPMessage at 0x7fc35a03a850>)

# %% [markdown]
# ## csv 파일로부터 데이터셋 만들기

# %% [markdown]
# csv.reader() 함수를 활용합니다.
#
# * 첫번째 파라미터에는 file을 , delimiter에는 구분자를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    i = 0
    for row in reader:
        print(row)
        i+=1
        if i > 10:
            break
# Out:
# ['0', '1749-01-31', '96.7']
# ['1', '1749-02-28', '104.3']
# ['2', '1749-03-31', '116.7']
# ['3', '1749-04-30', '92.8']
# ['4', '1749-05-31', '141.7']
# ['5', '1749-06-30', '139.2']
# ['6', '1749-07-31', '158.0']
# ['7', '1749-08-31', '110.5']
# ['8', '1749-09-30', '126.5']
# ['9', '1749-10-31', '125.8']
# ['10', '1749-11-30', '264.3']

# %% [markdown]
# 빈 list를 만들어 줍니다. (sunspots, time_step)

# %%
sunspots = []
time_step = []

# %% [markdown]
# `time_step`에는 **index** 값을, `sunspots`에는 sunspots의 정보를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    # 첫 줄은 header이므로 skip 합니다.
    next(reader)
    for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

# %% [markdown]
# sunspots, time_step 확인

# %%
sunspots[:5]
# Out:
# [96.7, 104.3, 116.7, 92.8, 141.7]

# %%
time_step[:5]
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# sunspots와 time_step을 `numpy array`로 변환합니다.
#
# * 참고: 모델은 list 타입을 받아들이지 못합니다. 따라서, numpy array 로 변환해 줍니다.

# %%
series = np.array(sunspots)
time = np.array(time_step)

# %%
series.shape, time.shape
# Out:
# ((3235,), (3235,))

# %% [markdown]
# ## 태양의 흑점 활동 (sunspots) 시각화

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
plt.plot(time, series)
plt.xlabel("Time")
plt.ylabel("Value")
plt.grid(True)

# %% [markdown]
# ## Train Set, Validation Set 생성

# %% [markdown]
# 3000 인덱스를 기준으로 Train / Validation Set를 분할 합니다.

# %%
split_time = 3000

# %%
time_train = time[:split_time] #3000까지 데이터 로드
time_valid = time[split_time:] #3000부터 나머지

x_train = series[:split_time]
x_valid = series[split_time:]

# %% [markdown]
# ## Window Dataset Loader

# %% [markdown]
# 자세한 Dataset 활용법은 [블로그 링크](https://teddylee777.github.io/tensorflow/dataset-batch-window)를 참고해 보시고, 연습해보세요!

# %%
# 윈도우 사이즈
window_size=30
# 배치 사이즈
batch_size = 32
# 셔플 사이즈
shuffle_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1) # prefetch(1) batch를 1개씩 더 만들어준다

# %% [markdown]
# `train_set`와 `validation_set`를 만듭니다.

# %%
train_set = windowed_dataset(x_train, 
                             window_size=window_size, 
                             batch_size=batch_size,
                             shuffle_buffer=shuffle_size)

validation_set = windowed_dataset(x_valid, 
                                  window_size=window_size,
                                  batch_size=batch_size,
                                  shuffle_buffer=shuffle_size)

# %% [markdown]
# ## 모델 정의 (Sequential)

# %%
from IPython.display import Image

Image('https://i.stack.imgur.com/NmYZJ.png')

# %%
model = Sequential([
    tf.keras.layers.Conv1D(60, kernel_size=5,
                         padding="causal",
                         activation="relu",
                         input_shape=[None, 1]),
    tf.keras.layers.LSTM(60, return_sequences=True), # Many to Many Model
    tf.keras.layers.LSTM(60, return_sequences=True),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# %% [markdown]
# 모델의 구조 요약을 확인합니다.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 60)          360
#
#  lstm (LSTM)                 (None, None, 60)          29040
#
#  lstm_1 (LSTM)               (None, None, 60)          29040
#
#  dense (Dense)               (None, None, 30)          1830
#
#  dense_1 (Dense)             (None, None, 10)          310
#
#  dense_2 (Dense)             (None, None, 1)           11
#
#  lambda (Lambda)             (None, None, 1)           0
#
# =================================================================
# Total params: 60,591
# Trainable params: 60,591
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 컴파일 (compile)

# %% [markdown]
# **Optimizer**는 SGD(Stochastic Gradient Descent) 를 사용합니다.
#
# * lr(learning_rate): 학습률입니다.
# * momentum: 모멘텀 (가중치) 입니다.

# %%
optimizer = SGD(learning_rate=1e-5, momentum=0.9)

# %% [markdown]
# **Huber Loss**: MSE와 MAE를 절충한 후버 손실(Huber loss)

# %% [markdown]
# \begin{split}L_{\delta}=\left\{\begin{matrix}
# \frac{1}{2}(y - \hat{y})^{2} & if \left | (y - \hat{y})  \right | < \delta\\
# \delta ((y - \hat{y}) - \frac1 2 \delta) & otherwise
# \end{matrix}\right.\end{split}

# %%
loss= Huber()

# %% [markdown]
# model.compile()시 우리가 튜닝한 **optimizer**와 **loss**를 활용합니다.

# %%
model.compile(loss=loss,
              optimizer=optimizer,
              metrics=["mae"])

# %% [markdown]
# ## ModelCheckpoint: 체크포인트 생성

# %% [markdown]
# `val_loss` 기준으로 epoch 마다 최적의 모델을 저장하기 위하여, ModelCheckpoint를 만듭니다.
# * `checkpoint_path`는 모델이 저장될 파일 명을 설정합니다.
# * `ModelCheckpoint`을 선언하고, 적절한 옵션 값을 지정합니다.

# %%
checkpoint_path = 'tmp_checkpoint.ckpt'
checkpoint = ModelCheckpoint(checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_mae',
                             verbose=1)

# %% [markdown]
# ## 학습 (fit)

# %%
epochs=100

# %%
history = model.fit(train_set, 
                    validation_data=(validation_set), 
                    epochs=epochs, 
                    callbacks=[checkpoint],
                   )
# Out:
# Epoch 1/100
#      90/Unknown - 15s 11ms/step - loss: 30.1803 - mae: 30.6752
# Epoch 1: val_mae improved from inf to 18.30949, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 16s 22ms/step - loss: 29.9293 - mae: 30.4241 - val_loss: 17.8161 - val_mae: 18.3095
# Epoch 2/100
# 90/93 [============================>.] - ETA: 0s - loss: 20.5875 - mae: 21.0804
# Epoch 2: val_mae improved from 18.30949 to 16.80935, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 20.5749 - mae: 21.0677 - val_loss: 16.3189 - val_mae: 16.8093
# Epoch 3/100
# 91/93 [============================>.] - ETA: 0s - loss: 19.9166 - mae: 20.4091
# Epoch 3: val_mae improved from 16.80935 to 15.48736, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 19.9151 - mae: 20.4077 - val_loss: 14.9967 - val_mae: 15.4874
# Epoch 4/100
# 93/93 [==============================] - ETA: 0s - loss: 19.0851 - mae: 19.5778
# Epoch 4: val_mae improved from 15.48736 to 15.19685, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 19.0851 - mae: 19.5778 - val_loss: 14.7050 - val_mae: 15.1968
# Epoch 5/100
# 92/93 [============================>.] - ETA: 0s - loss: 18.8281 - mae: 19.3204
# Epoch 5: val_mae did not improve from 15.19685
# 93/93 [==============================] - 1s 11ms/step - loss: 18.8233 - mae: 19.3157 - val_loss: 14.7215 - val_mae: 15.2134
# Epoch 6/100
# 89/93 [===========================>..] - ETA: 0s - loss: 18.5964 - mae: 19.0882
# Epoch 6: val_mae did not improve from 15.19685
# 93/93 [==============================] - 1s 11ms/step - loss: 18.5479 - mae: 19.0396 - val_loss: 14.7824 - val_mae: 15.2756
# Epoch 7/100
# 93/93 [==============================] - ETA: 0s - loss: 18.9986 - mae: 19.4908
# Epoch 7: val_mae did not improve from 15.19685
# 93/93 [==============================] - 1s 11ms/step - loss: 18.9986 - mae: 19.4908 - val_loss: 14.8929 - val_mae: 15.3850
# Epoch 8/100
# 93/93 [==============================] - ETA: 0s - loss: 18.3194 - mae: 18.8113
# Epoch 8: val_mae improved from 15.19685 to 14.35903, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 18.3194 - mae: 18.8113 - val_loss: 13.8670 - val_mae: 14.3590
# Epoch 9/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.9273 - mae: 18.4191
# Epoch 9: val_mae did not improve from 14.35903
# 93/93 [==============================] - 1s 11ms/step - loss: 17.9355 - mae: 18.4273 - val_loss: 14.2242 - val_mae: 14.7167
# Epoch 10/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.8440 - mae: 18.3358
# Epoch 10: val_mae did not improve from 14.35903
# 93/93 [==============================] - 1s 11ms/step - loss: 17.8948 - mae: 18.3866 - val_loss: 14.0790 - val_mae: 14.5688
# Epoch 11/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.5763 - mae: 18.0679
# Epoch 11: val_mae improved from 14.35903 to 14.30829, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5566 - mae: 18.0482 - val_loss: 13.8197 - val_mae: 14.3083
# Epoch 12/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.5061 - mae: 17.9975
# Epoch 12: val_mae improved from 14.30829 to 14.16117, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.4882 - mae: 17.9795 - val_loss: 13.6708 - val_mae: 14.1612
# Epoch 13/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.8834 - mae: 18.3749
# Epoch 13: val_mae did not improve from 14.16117
# 93/93 [==============================] - 1s 11ms/step - loss: 17.8474 - mae: 18.3389 - val_loss: 13.9052 - val_mae: 14.3950
# Epoch 14/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.4988 - mae: 17.9901
# Epoch 14: val_mae did not improve from 14.16117
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5566 - mae: 18.0480 - val_loss: 14.2649 - val_mae: 14.7543
# Epoch 15/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.5316 - mae: 18.0228
# Epoch 15: val_mae did not improve from 14.16117
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5208 - mae: 18.0119 - val_loss: 13.6998 - val_mae: 14.1885
# Epoch 16/100
# 87/93 [===========================>..] - ETA: 0s - loss: 17.3879 - mae: 17.8788
# Epoch 16: val_mae did not improve from 14.16117
# 93/93 [==============================] - 1s 11ms/step - loss: 17.4088 - mae: 17.8998 - val_loss: 15.5246 - val_mae: 16.0173
# Epoch 17/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.4971 - mae: 17.9884
# Epoch 17: val_mae improved from 14.16117 to 14.07946, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5036 - mae: 17.9949 - val_loss: 13.5901 - val_mae: 14.0795
# Epoch 18/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.4977 - mae: 17.9891
# Epoch 18: val_mae did not improve from 14.07946
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5367 - mae: 18.0282 - val_loss: 13.7868 - val_mae: 14.2749
# Epoch 19/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.7476 - mae: 18.2392
# Epoch 19: val_mae improved from 14.07946 to 13.99714, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.7367 - mae: 18.2282 - val_loss: 13.5082 - val_mae: 13.9971
# Epoch 20/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.6510 - mae: 18.1421
# Epoch 20: val_mae did not improve from 13.99714
# 93/93 [==============================] - 1s 11ms/step - loss: 17.7099 - mae: 18.2011 - val_loss: 14.0962 - val_mae: 14.5843
# Epoch 21/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.3882 - mae: 17.8789
# Epoch 21: val_mae did not improve from 13.99714
# 93/93 [==============================] - 1s 11ms/step - loss: 17.3665 - mae: 17.8573 - val_loss: 13.5834 - val_mae: 14.0709
# Epoch 22/100
# 93/93 [==============================] - ETA: 0s - loss: 17.3732 - mae: 17.8640
# Epoch 22: val_mae did not improve from 13.99714
# 93/93 [==============================] - 1s 11ms/step - loss: 17.3732 - mae: 17.8640 - val_loss: 13.5883 - val_mae: 14.0789
# Epoch 23/100
# 93/93 [==============================] - ETA: 0s - loss: 17.4889 - mae: 17.9799
# Epoch 23: val_mae improved from 13.99714 to 13.87090, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.4889 - mae: 17.9799 - val_loss: 13.3821 - val_mae: 13.8709
# Epoch 24/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.3718 - mae: 17.8628
# Epoch 24: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 11ms/step - loss: 17.4603 - mae: 17.9515 - val_loss: 13.5273 - val_mae: 14.0152
# Epoch 25/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.4368 - mae: 17.9275
# Epoch 25: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 12ms/step - loss: 17.4624 - mae: 17.9532 - val_loss: 13.4612 - val_mae: 13.9517
# Epoch 26/100
# 93/93 [==============================] - ETA: 0s - loss: 17.1923 - mae: 17.6832
# Epoch 26: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 12ms/step - loss: 17.1923 - mae: 17.6832 - val_loss: 13.6164 - val_mae: 14.1064
# Epoch 27/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.1326 - mae: 17.6230
# Epoch 27: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1472 - mae: 17.6377 - val_loss: 13.7140 - val_mae: 14.2029
# Epoch 28/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.2319 - mae: 17.7226
# Epoch 28: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 11ms/step - loss: 17.2329 - mae: 17.7236 - val_loss: 13.8893 - val_mae: 14.3784
# Epoch 29/100
# 93/93 [==============================] - ETA: 0s - loss: 17.5811 - mae: 18.0722
# Epoch 29: val_mae did not improve from 13.87090
# 93/93 [==============================] - 1s 11ms/step - loss: 17.5811 - mae: 18.0722 - val_loss: 14.2979 - val_mae: 14.7876
# Epoch 30/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.1181 - mae: 17.6088
# Epoch 30: val_mae improved from 13.87090 to 13.79096, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1195 - mae: 17.6103 - val_loss: 13.3010 - val_mae: 13.7910
# Epoch 31/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.6031 - mae: 18.0939
# Epoch 31: val_mae did not improve from 13.79096
# 93/93 [==============================] - 1s 11ms/step - loss: 17.6010 - mae: 18.0918 - val_loss: 14.0896 - val_mae: 14.5794
# Epoch 32/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.0929 - mae: 17.5837
# Epoch 32: val_mae did not improve from 13.79096
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1002 - mae: 17.5910 - val_loss: 13.3113 - val_mae: 13.7995
# Epoch 33/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.0375 - mae: 17.5283
# Epoch 33: val_mae improved from 13.79096 to 13.77008, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 12ms/step - loss: 17.0479 - mae: 17.5387 - val_loss: 13.2816 - val_mae: 13.7701
# Epoch 34/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.0670 - mae: 17.5575
# Epoch 34: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.0839 - mae: 17.5743 - val_loss: 13.4366 - val_mae: 13.9256
# Epoch 35/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.0546 - mae: 17.5451
# Epoch 35: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 12ms/step - loss: 17.0527 - mae: 17.5432 - val_loss: 16.2175 - val_mae: 16.7098
# Epoch 36/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.2627 - mae: 17.7536
# Epoch 36: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.3048 - mae: 17.7957 - val_loss: 13.5104 - val_mae: 14.0002
# Epoch 37/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.1585 - mae: 17.6492
# Epoch 37: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1332 - mae: 17.6239 - val_loss: 14.1085 - val_mae: 14.5987
# Epoch 38/100
# 93/93 [==============================] - ETA: 0s - loss: 17.1121 - mae: 17.6029
# Epoch 38: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1121 - mae: 17.6029 - val_loss: 13.7350 - val_mae: 14.2259
# Epoch 39/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.1239 - mae: 17.6147
# Epoch 39: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.1049 - mae: 17.5957 - val_loss: 13.4989 - val_mae: 13.9884
# Epoch 40/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.9327 - mae: 17.4234
# Epoch 40: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9422 - mae: 17.4329 - val_loss: 13.2826 - val_mae: 13.7714
# Epoch 41/100
# 93/93 [==============================] - ETA: 0s - loss: 17.0666 - mae: 17.5568
# Epoch 41: val_mae did not improve from 13.77008
# 93/93 [==============================] - 2s 18ms/step - loss: 17.0666 - mae: 17.5568 - val_loss: 13.3895 - val_mae: 13.8768
# Epoch 42/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.9994 - mae: 17.4896
# Epoch 42: val_mae did not improve from 13.77008
# 93/93 [==============================] - 2s 15ms/step - loss: 17.0103 - mae: 17.5005 - val_loss: 13.3775 - val_mae: 13.8661
# Epoch 43/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.9299 - mae: 17.4199
# Epoch 43: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9396 - mae: 17.4296 - val_loss: 13.2913 - val_mae: 13.7808
# Epoch 44/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.9089 - mae: 17.3989
# Epoch 44: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9243 - mae: 17.4144 - val_loss: 13.3940 - val_mae: 13.8829
# Epoch 45/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9526 - mae: 17.4429
# Epoch 45: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9526 - mae: 17.4429 - val_loss: 13.6177 - val_mae: 14.1051
# Epoch 46/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.9390 - mae: 17.4295
# Epoch 46: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9069 - mae: 17.3974 - val_loss: 13.6134 - val_mae: 14.1027
# Epoch 47/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8844 - mae: 17.3742
# Epoch 47: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.8935 - mae: 17.3832 - val_loss: 13.6019 - val_mae: 14.0910
# Epoch 48/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.9090 - mae: 17.3994
# Epoch 48: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9506 - mae: 17.4411 - val_loss: 14.5631 - val_mae: 15.0535
# Epoch 49/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8394 - mae: 17.3297
# Epoch 49: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.8638 - mae: 17.3541 - val_loss: 13.5508 - val_mae: 14.0430
# Epoch 50/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9542 - mae: 17.4444
# Epoch 50: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9542 - mae: 17.4444 - val_loss: 13.7654 - val_mae: 14.2529
# Epoch 51/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.8264 - mae: 17.3167
# Epoch 51: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.8535 - mae: 17.3437 - val_loss: 13.4863 - val_mae: 13.9754
# Epoch 52/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.9874 - mae: 17.4781
# Epoch 52: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9747 - mae: 17.4654 - val_loss: 13.3698 - val_mae: 13.8567
# Epoch 53/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.7061 - mae: 17.1958
# Epoch 53: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.7627 - mae: 17.2524 - val_loss: 13.2998 - val_mae: 13.7865
# Epoch 54/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.8435 - mae: 17.3340
# Epoch 54: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.8323 - mae: 17.3228 - val_loss: 13.4020 - val_mae: 13.8896
# Epoch 55/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.0002 - mae: 17.4907
# Epoch 55: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.0068 - mae: 17.4973 - val_loss: 13.3687 - val_mae: 13.8580
# Epoch 56/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.9609 - mae: 17.4514
# Epoch 56: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.9576 - mae: 17.4481 - val_loss: 14.2344 - val_mae: 14.7232
# Epoch 57/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8643 - mae: 17.3545
# Epoch 57: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.8660 - mae: 17.3562 - val_loss: 14.0362 - val_mae: 14.5240
# Epoch 58/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.9615 - mae: 17.4514
# Epoch 58: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9462 - mae: 17.4361 - val_loss: 13.3484 - val_mae: 13.8365
# Epoch 59/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.7137 - mae: 17.2036
# Epoch 59: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 16.6980 - mae: 17.1879 - val_loss: 14.4609 - val_mae: 14.9519
# Epoch 60/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.9693 - mae: 17.4600
# Epoch 60: val_mae did not improve from 13.77008
# 93/93 [==============================] - 1s 11ms/step - loss: 17.0075 - mae: 17.4982 - val_loss: 13.3034 - val_mae: 13.7920
# Epoch 61/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.7983 - mae: 17.2886
# Epoch 61: val_mae improved from 13.77008 to 13.76506, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7898 - mae: 17.2801 - val_loss: 13.2784 - val_mae: 13.7651
# Epoch 62/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.7177 - mae: 17.2079
# Epoch 62: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7046 - mae: 17.1948 - val_loss: 13.3560 - val_mae: 13.8460
# Epoch 63/100
# 93/93 [==============================] - ETA: 0s - loss: 16.8714 - mae: 17.3614
# Epoch 63: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.8714 - mae: 17.3614 - val_loss: 13.5871 - val_mae: 14.0747
# Epoch 64/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.6665 - mae: 17.1564
# Epoch 64: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6778 - mae: 17.1676 - val_loss: 13.6622 - val_mae: 14.1522
# Epoch 65/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.6640 - mae: 17.1538
# Epoch 65: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6868 - mae: 17.1767 - val_loss: 13.6420 - val_mae: 14.1276
# Epoch 66/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9078 - mae: 17.3982
# Epoch 66: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9078 - mae: 17.3982 - val_loss: 13.3963 - val_mae: 13.8846
# Epoch 67/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.5771 - mae: 17.0669
# Epoch 67: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 11ms/step - loss: 16.6138 - mae: 17.1037 - val_loss: 13.2847 - val_mae: 13.7738
# Epoch 68/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8894 - mae: 17.3790
# Epoch 68: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 12ms/step - loss: 16.8628 - mae: 17.3524 - val_loss: 14.1438 - val_mae: 14.6329
# Epoch 69/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.6504 - mae: 17.1403
# Epoch 69: val_mae did not improve from 13.76506
# 93/93 [==============================] - 1s 11ms/step - loss: 16.6410 - mae: 17.1308 - val_loss: 13.3449 - val_mae: 13.8351
# Epoch 70/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.6871 - mae: 17.1768
# Epoch 70: val_mae improved from 13.76506 to 13.74505, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6860 - mae: 17.1759 - val_loss: 13.2561 - val_mae: 13.7450
# Epoch 71/100
# 87/93 [===========================>..] - ETA: 0s - loss: 16.7454 - mae: 17.2353
# Epoch 71: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7410 - mae: 17.2309 - val_loss: 13.6769 - val_mae: 14.1652
# Epoch 72/100
# 93/93 [==============================] - ETA: 0s - loss: 16.6607 - mae: 17.1509
# Epoch 72: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6607 - mae: 17.1509 - val_loss: 13.3039 - val_mae: 13.7923
# Epoch 73/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.5846 - mae: 17.0744
# Epoch 73: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5850 - mae: 17.0749 - val_loss: 13.2668 - val_mae: 13.7572
# Epoch 74/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.5166 - mae: 17.0062
# Epoch 74: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5279 - mae: 17.0175 - val_loss: 13.3015 - val_mae: 13.7920
# Epoch 75/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.5260 - mae: 17.0154
# Epoch 75: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 12ms/step - loss: 16.5653 - mae: 17.0548 - val_loss: 13.5613 - val_mae: 14.0508
# Epoch 76/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5206 - mae: 17.0099
# Epoch 76: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5449 - mae: 17.0344 - val_loss: 13.2955 - val_mae: 13.7832
# Epoch 77/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.6541 - mae: 17.1437
# Epoch 77: val_mae did not improve from 13.74505
# 93/93 [==============================] - 1s 11ms/step - loss: 16.6294 - mae: 17.1190 - val_loss: 13.4001 - val_mae: 13.8913
# Epoch 78/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.5322 - mae: 17.0217
# Epoch 78: val_mae improved from 13.74505 to 13.70704, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 12ms/step - loss: 16.5572 - mae: 17.0468 - val_loss: 13.2170 - val_mae: 13.7070
# Epoch 79/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.6566 - mae: 17.1469
# Epoch 79: val_mae improved from 13.70704 to 13.65739, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6203 - mae: 17.1105 - val_loss: 13.1695 - val_mae: 13.6574
# Epoch 80/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5220 - mae: 17.0114
# Epoch 80: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.5065 - mae: 16.9958 - val_loss: 13.6041 - val_mae: 14.0933
# Epoch 81/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.5217 - mae: 17.0114
# Epoch 81: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5224 - mae: 17.0122 - val_loss: 14.1672 - val_mae: 14.6563
# Epoch 82/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5383 - mae: 17.0282
# Epoch 82: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5818 - mae: 17.0718 - val_loss: 14.1296 - val_mae: 14.6181
# Epoch 83/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.4776 - mae: 16.9677
# Epoch 83: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5282 - mae: 17.0183 - val_loss: 13.4954 - val_mae: 13.9842
# Epoch 84/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.4612 - mae: 16.9510
# Epoch 84: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4697 - mae: 16.9595 - val_loss: 13.4527 - val_mae: 13.9380
# Epoch 85/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.5029 - mae: 16.9924
# Epoch 85: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5092 - mae: 16.9987 - val_loss: 13.8201 - val_mae: 14.3080
# Epoch 86/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.4479 - mae: 16.9376
# Epoch 86: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4460 - mae: 16.9357 - val_loss: 13.6460 - val_mae: 14.1353
# Epoch 87/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5274 - mae: 17.0169
# Epoch 87: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4885 - mae: 16.9779 - val_loss: 15.4152 - val_mae: 15.9060
# Epoch 88/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.6068 - mae: 17.0962
# Epoch 88: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.6129 - mae: 17.1023 - val_loss: 14.1881 - val_mae: 14.6771
# Epoch 89/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.4293 - mae: 16.9189
# Epoch 89: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4171 - mae: 16.9068 - val_loss: 13.5069 - val_mae: 13.9980
# Epoch 90/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.5506 - mae: 17.0400
# Epoch 90: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.5686 - mae: 17.0580 - val_loss: 13.6224 - val_mae: 14.1116
# Epoch 91/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3390 - mae: 16.8284
# Epoch 91: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.3572 - mae: 16.8467 - val_loss: 13.6141 - val_mae: 14.1030
# Epoch 92/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.3297 - mae: 16.8194
# Epoch 92: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.3283 - mae: 16.8180 - val_loss: 13.4111 - val_mae: 13.9005
# Epoch 93/100
# 93/93 [==============================] - ETA: 0s - loss: 16.3531 - mae: 16.8423
# Epoch 93: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3531 - mae: 16.8423 - val_loss: 15.2412 - val_mae: 15.7308
# Epoch 94/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.4328 - mae: 16.9224
# Epoch 94: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4593 - mae: 16.9490 - val_loss: 14.0044 - val_mae: 14.4928
# Epoch 95/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.4152 - mae: 16.9043
# Epoch 95: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.4606 - mae: 16.9498 - val_loss: 13.5259 - val_mae: 14.0178
# Epoch 96/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3418 - mae: 16.8312
# Epoch 96: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3603 - mae: 16.8499 - val_loss: 13.7864 - val_mae: 14.2770
# Epoch 97/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.3307 - mae: 16.8201
# Epoch 97: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.3477 - mae: 16.8371 - val_loss: 13.4841 - val_mae: 13.9734
# Epoch 98/100
# 93/93 [==============================] - ETA: 0s - loss: 16.3519 - mae: 16.8415
# Epoch 98: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3519 - mae: 16.8415 - val_loss: 13.4627 - val_mae: 13.9524
# Epoch 99/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.5125 - mae: 17.0021
# Epoch 99: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.5065 - mae: 16.9962 - val_loss: 13.7613 - val_mae: 14.2514
# Epoch 100/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.3673 - mae: 16.8568
# Epoch 100: val_mae did not improve from 13.65739
# 93/93 [==============================] - 1s 11ms/step - loss: 16.3703 - mae: 16.8597 - val_loss: 13.6596 - val_mae: 14.1508

# %% [markdown]
# ## 학습 완료 후 Load Weights (ModelCheckpoint)

# %% [markdown]
# 학습이 완료된 후에는 반드시 `load_weights`를 해주어야 합니다.
#
# 그렇지 않으면, 열심히 ModelCheckpoint를 만든 의미가 없습니다.

# %%
model.load_weights(checkpoint_path)

# %% [markdown]
# ## 학습 오차에 대한 시각화

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['loss'])
plt.plot(np.arange(1, epochs+1), history.history['val_loss'])
plt.title('Loss / Val Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'], fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['mae'])
plt.plot(np.arange(1, epochs+1), history.history['val_mae'])
plt.title('MAE / Val MAE', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend(['mae', 'val_mae'], fontsize=15)
plt.show()
