# %% [markdown]
# <a href="https://colab.research.google.com/github/Stacy067/Deep-learning-and-Tensorflow/blob/main/TF2_fashion_mnist_(%EB%AC%B8%EC%A0%9C)%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets Question
#
# Create a classifier for the Fashion MNIST dataset
# Note that the test will expect it to classify 10 classes and that the 
# input shape should be the native size of the Fashion MNIST dataset which is 
# 28x28 monochrome. Do not resize the data. YOur input layer should accept
# (28,28) as the input shape only. If you amend this, the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - fashion mnist
# val_loss: 0.33
# val_acc: 0.89
# =================================================== #
# =================================================== #

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_valid, y_valid) = fashion_mnist.load_data()
x_train =x_train / 255.0
x_valid =x_valid / 255.0

def solution_model():
        # YOUR CODE HERE
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(1024, activation='relu',),
        Dense(512, activation='relu',),
        Dense(256, activation='relu',),
        Dense(128, activation='relu',),
        Dense(64, activation='relu',),
        Dense(10, activation='softmax',),
    ])
    model.compile(optimizer ='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
    checkpoint_path = "shkim_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                                save_weights_only=True,
                                save_best_only=True,
                                monitor="val_loss",
                                verbose=1)
    model.fit(x_train, y_train,
              validation_data=(x_valid, y_valid),
              epochs=20,
              callbacks=[checkpoint]
              )
    model.load_weights(checkpoint_path)
    model.evaluate(x_valid, y_valid)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF2-fashion-mnist.h5")
# Out:
# Epoch 1/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.5005 - acc: 0.8209
# Epoch 1: val_loss improved from inf to 0.42603, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.5005 - acc: 0.8209 - val_loss: 0.4260 - val_acc: 0.8501
# Epoch 2/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.3776 - acc: 0.8624
# Epoch 2: val_loss improved from 0.42603 to 0.38254, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3778 - acc: 0.8623 - val_loss: 0.3825 - val_acc: 0.8639
# Epoch 3/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.3377 - acc: 0.8770
# Epoch 3: val_loss did not improve from 0.38254
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.3377 - acc: 0.8770 - val_loss: 0.4156 - val_acc: 0.8585
# Epoch 4/20
# 1875/1875 [==============================] - ETA: 0s - loss: 0.3159 - acc: 0.8849
# Epoch 4: val_loss improved from 0.38254 to 0.35416, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.3159 - acc: 0.8849 - val_loss: 0.3542 - val_acc: 0.8759
# Epoch 5/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2967 - acc: 0.8914
# Epoch 5: val_loss did not improve from 0.35416
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2968 - acc: 0.8913 - val_loss: 0.3543 - val_acc: 0.8788
# Epoch 6/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2804 - acc: 0.8965
# Epoch 6: val_loss improved from 0.35416 to 0.35049, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2804 - acc: 0.8965 - val_loss: 0.3505 - val_acc: 0.8815
# Epoch 7/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2672 - acc: 0.9005
# Epoch 7: val_loss did not improve from 0.35049
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2670 - acc: 0.9006 - val_loss: 0.3610 - val_acc: 0.8779
# Epoch 8/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2585 - acc: 0.9047
# Epoch 8: val_loss improved from 0.35049 to 0.33591, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2584 - acc: 0.9047 - val_loss: 0.3359 - val_acc: 0.8847
# Epoch 9/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2467 - acc: 0.9085
# Epoch 9: val_loss improved from 0.33591 to 0.32772, saving model to shkim_checkpoint.ckpt
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2467 - acc: 0.9085 - val_loss: 0.3277 - val_acc: 0.8884
# Epoch 10/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2403 - acc: 0.9108
# Epoch 10: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2403 - acc: 0.9108 - val_loss: 0.3445 - val_acc: 0.8838
# Epoch 11/20
# 1875/1875 [==============================] - ETA: 0s - loss: 0.2314 - acc: 0.9129
# Epoch 11: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2314 - acc: 0.9129 - val_loss: 0.3563 - val_acc: 0.8838
# Epoch 12/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2236 - acc: 0.9176
# Epoch 12: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2236 - acc: 0.9176 - val_loss: 0.3781 - val_acc: 0.8790
# Epoch 13/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2161 - acc: 0.9189
# Epoch 13: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2160 - acc: 0.9189 - val_loss: 0.4001 - val_acc: 0.8772
# Epoch 14/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.2119 - acc: 0.9208
# Epoch 14: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2119 - acc: 0.9209 - val_loss: 0.3518 - val_acc: 0.8890
# Epoch 15/20
# 1875/1875 [==============================] - ETA: 0s - loss: 0.2050 - acc: 0.9230
# Epoch 15: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2050 - acc: 0.9230 - val_loss: 0.3557 - val_acc: 0.8856
# Epoch 16/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1985 - acc: 0.9257
# Epoch 16: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1985 - acc: 0.9257 - val_loss: 0.3653 - val_acc: 0.8871
# Epoch 17/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1945 - acc: 0.9271
# Epoch 17: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1944 - acc: 0.9271 - val_loss: 0.3974 - val_acc: 0.8854
# Epoch 18/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1884 - acc: 0.9279
# Epoch 18: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1884 - acc: 0.9279 - val_loss: 0.3922 - val_acc: 0.8848
# Epoch 19/20
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1856 - acc: 0.9305
# Epoch 19: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1857 - acc: 0.9305 - val_loss: 0.3657 - val_acc: 0.8959
# Epoch 20/20
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1768 - acc: 0.9336
# Epoch 20: val_loss did not improve from 0.32772
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1769 - acc: 0.9335 - val_loss: 0.4240 - val_acc: 0.8827
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3277 - acc: 0.8884
